# %% [markdown]
# # Working with Categorical data - PRACTICE

# %% [markdown]
# ## Practice Skills on each of below datasets
#
# 1. Ability to identify categorical and numerical columns.
# 2. Ability to identify categorical columns with less than 10 features ( try with 5 and 7 features as well)
# 3. Try the three approaches we discussed
#     1. Drop Categorical variables
#     2. Lable encoding
#     3. One Hot encoding.
# 4. Use your understanding of MAE scores in Linear Regression to write a function to assess MAE for each of the 3 approaches.
#
# You can allways refer to our [sample notebook when in doubt.](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/Working%20with%20categorical%20data.ipynb)
#
# > All the best. I hope you enjoy working on these datasets, as much as i have enjoyed putting these together.

# %% [markdown]
# ![housesbanner.png](attachment:housesbanner.png)
#
# ### AMES HOUSING
#
# This is a perfect dataset for those who are looking to expand their skill on working with categorical data.
#
# ### Data Description
#
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this dataset challenges you to showcase your skills in handling categorical data.
#
# [Description of variables](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/data/ames_housing_description.txt)
#
# [Train Data-set](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/data/ames_housing_train.csv)
#
# [Test Data-set](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/data/ames_housing_test.csv)
#
# ### Acknowledgments
#
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset. I picked up this data-set from [here]9https://www.kaggle.com/c/home-data-for-ml-course/overview), you will find many notebooks there, if you are interested.

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## CAT THE DAT CHALLANGE
#
# ![cat7.jpg](attachment:cat7.jpg)
#
# Is there a cat in your dat?
#
# A common task in machine learning pipelines is encoding categorical variables for a given algorithm in a format that allows as much useful signal as possible to be captured.
#
# Because this is such a common task and important skill to master, we've put together a dataset that contains only categorical features, and includes:
#
# +    binary features
# +    low- and high-cardinality nominal features
# +    low- and high-cardinality ordinal features
# +    (potentially) cyclical features
#
# This Playground dataset will give you the opportunity to try different encoding schemes for different algorithms to compare how they perform.
#
# [You can find and download the data from here](https://www.kaggle.com/c/cat-in-the-dat/data)

# %% [markdown]
# ***
# ***

# %% [markdown]
# ![dataset-cover.jpg](attachment:dataset-cover.jpg)
#
# ## Automobile import dataset
#
#
# ### Context
#
# This dataset consist of data From 1985 Ward's Automotive Yearbook. Here are the sources
#
# ### Dataset & description:
#
# [Dataset](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/data/auto_imports.csv)
# [Description](https://github.com/bharathkreddy/ML-Bootcamp/blob/master/data/auto_imports.names)
#
# If you want a ready made CSV file - [find it here](https://www.kaggle.com/toramky/automobile-dataset) ( but i want you to get comfortable reading Descriptions and creating your own datasets - trust me, it would be very rewarding later)
#
# ### Content
#
# This data set consists of three types of entities: (a) the specification of an auto in terms of various characteristics, (b) its assigned insurance risk rating, (c) its normalized losses in use as compared to other cars. The second rating corresponds to the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale. Actuarians call this process "symboling". A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
#
# The third factor is the relative average loss payment per insured vehicle year. This value is normalized for all autos within a particular size classification (two-door small, station wagons, sports/speciality, etc…), and represents the average loss per car per year.
#
# Note: Several of the attributes in the database could be used as a "class" attribute.
#
# ### NOTES
#
# 1. Several of the attributes in the database could be used as a "class" attribute.
# 2. Read the information about the dataset carefully.
# 3. You might need to drop a few columns - decide wisely and justify which column you drop.
# 4. While working on this dataset - dont forget to have fun.
# 5. You would be requried to use your understanding of
#     1. Missing values
#     2. Categorical values
# 6. For more adventurous of you, After working on missing values and categorical data - you can use Linear regression to predict the prices.
# 7. While working on this dataset - dont forget to have fun and enjoy the process.
#
#
# > Journey is often more fun and relavent than the destination.
# >                  -Grand Master Oogway
